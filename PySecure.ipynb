# %%
import subprocess
result = subprocess.run(['python', 'main.py', '--target', '127.0.0.1'], 
                       capture_output=True, text=True)
print(result.stdout)
# Out:
# Created requirements.txt
#
# ...
# PySecure Scanner - Command Line Mode
# ...
#
# [*] Target: 127.0.0.1
# [*] Ports: Default
# [*] Threads: 30
# [*] Timeout: 2.0s
# [*] Banner grab: No
# [*] Vuln scan: No
# ------------------------------------------------------------
# [*] Starting scan...
# [*] Starting scan on 1 target(s)
# [*] Scanning 18 port(s) per target
# [*] Using 30 threads
# [*] Timeout: 2.0s
# --------------------------------------------------
#
# [*] Progress: [â–ˆâ–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘] 5.6% (1/18)
# [*] Progress: [â–ˆâ–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘] 5.6% (1/18)
# [*] Progress: [â–ˆâ–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘] 5.6% (1/18)
# [*] Progress: [â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘â–‘] 61.1% (11/18)
# ...
